# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import gmaps.datasets
import os
from ipywidgets.embed import embed_minimal_html

# Import API key
from api_keys import g_key

gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
fpath = '../output_data/NathanAsh_cities.csv'

city = pd.read_csv(fpath)
city
# Out:
#      Unnamed: 0               City  Latitude  Longitude  Max Tempurature (F)  \
# 0             1        shubarkuduk     49.14      56.49               68.126
# 1             3          upernavik     72.79     -56.15               40.064
# 2             5         butaritari      3.07     172.79               81.518
# 3             7              vardo     70.37      31.11               51.800
# 4            11          ilulissat     69.22     -51.10               46.400
# ..          ...                ...       ...        ...                  ...
# 545         629       puerto lopez      4.08     -72.96               83.804
# 546         630           buraydah     26.33      43.98               91.400
# 547         631             bedesa      8.90      40.78               66.326
# 548         632  verkhneye dubrovo     56.75      61.05               48.200
# 549         633             amiens     49.90       2.30               75.200
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 0            72.0              95              0.37  1597353718
# 1            92.0             100             11.24  1597353483
# 2            69.0             100              0.98  1597353719
# 3            71.0             100              3.60  1597353720
# 4            52.0             100              6.70  1597353720
# ..            ...             ...               ...         ...
# 545          74.0              82              1.61  1597353816
# 546          24.0               0              2.10  1597353656
# 547          78.0              98              1.61  1597353816
# 548          93.0              98              1.00  1597353816
# 549          64.0              78              3.60  1597353748
#
# [550 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
loc = city[['Latitude','Longitude']]
hum = city['Humidity (%)'].astype(float)

# %%
fig = gmaps.figure()
heatH = gmaps.heatmap_layer(loc,weights = hum, 
                           dissipating = False, max_intensity = 10,
                           point_radius = 1)
fig.add_layer(heatH)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal = city.copy()
# ideal['Humidity']  = pd.to_numeric(ideal['Humidity'])

# for index,row in city_df.iterrows():
ideal = ideal.loc[ideal['Max Tempurature (F)'].gt(80) == False]
ideal = ideal.loc[ideal['Max Tempurature (F)'].gt(70) == True]
ideal = ideal.loc[ideal['Wind Speed (mph)'].gt(10) == False]
ideal = ideal.loc[ideal['Cloudiness (%)'].gt(0) == False]
ideal = ideal.dropna(how = 'any')
ideal
# Out:
#      Unnamed: 0               City  Latitude  Longitude  Max Tempurature (F)  \
# 67          120               axim      4.87      -2.24               74.750
# 76          129       komsomolskiy     40.43      71.72               71.600
# 80          135  sao joao da barra    -21.64     -41.05               75.200
# 106         163           ajdabiya     30.76      20.23               78.638
# 113         171            nangong     37.36     115.37               74.444
# 127         188            mumford      5.26      -0.76               73.580
# 133         194       marsa matruh     31.35      27.25               78.800
# 148         209             harper      4.38      -7.72               74.804
# 173         234         abu samrah     35.30      37.18               73.310
# 260         329             mizdah     31.45      12.98               77.324
# 342         415             darnah     32.77      22.64               78.620
# 351         425        chake chake     -5.25      39.77               72.986
# 353         427              pafos     34.77      32.42               75.200
# 391         469            bocanda      7.06      -4.50               74.570
# 429         508             jiexiu     37.02     111.91               72.752
# 445         525               gela     37.08      14.23               78.008
# 449         529              tabou      4.42      -7.35               75.128
# 483         563          karpathos     35.51      27.21               78.800
# 486         566          archidona     37.10      -4.39               75.992
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 67           80.0               0              4.05  1597353737
# 76           40.0               0              5.10  1597353739
# 80           73.0               0              8.20  1597353740
# 106          64.0               0              6.87  1597353745
# 113          95.0               0              2.74  1597353746
# 127          89.0               0              4.46  1597353749
# 133          78.0               0              4.10  1597353749
# 148          78.0               0              2.84  1597353752
# 173          62.0               0              3.65  1597353756
# 260          45.0               0              7.17  1597353770
# 342          83.0               0              7.24  1597353783
# 351          78.0               0              3.89  1597353785
# 353          83.0               0              4.10  1597353785
# 391          77.0               0              1.21  1597353791
# 429          54.0               0              1.06  1597353797
# 445          61.0               0              0.50  1597353800
# 449          78.0               0              2.69  1597353800
# 483          78.0               0              5.70  1597353805
# 486          57.0               0              0.45  1597353806

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#For loop 

params = {
    "radius": 50000,
    "type": "lodging",
    "key": g_key
}


ideal["Hotel Name"] = ""

for index, row in ideal.iterrows():
    lat = row['Latitude']
    lng = row['Longitude']

    params['location'] = f"{lat},{lng}"
#     print(params)
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    urlpar = requests.get(url,  params=params)
    print(urlpar)
    urlpar = urlpar.json()
    try:
        ideal.loc[index, 'Hotel Name'] = hotels['results'][0]['name']
    except:
        print(f'Hotel in {row[1]} not found')
ideal
    
urlpar
#     print(urlpar)
# Out:
# <Response [200]>
# Hotel in axim not found
# <Response [200]>
# Hotel in komsomolskiy not found
# <Response [200]>
# Hotel in sao joao da barra not found
# <Response [200]>
# Hotel in ajdabiya not found
# <Response [200]>
# Hotel in nangong not found
# <Response [200]>
# Hotel in mumford not found
# <Response [200]>
# Hotel in marsa matruh not found
# <Response [200]>
# Hotel in harper not found
# <Response [200]>
# Hotel in abu samrah not found
# <Response [200]>
# Hotel in mizdah not found
# <Response [200]>
# Hotel in darnah not found
# <Response [200]>
# Hotel in chake chake not found
# <Response [200]>
# Hotel in pafos not found
# <Response [200]>
# Hotel in bocanda not found
# <Response [200]>
# Hotel in jiexiu not found
# <Response [200]>
# Hotel in gela not found
# <Response [200]>
# Hotel in tabou not found
# <Response [200]>
# Hotel in karpathos not found
# <Response [200]>
# Hotel in archidona not found
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAALh0bWq2kkpSy1p5Pb2pABpM-0BKfs1s-exH8NwGSzTj6T_ImSoDwYjYBzNiQe9IkVltoB9sWuTzJ1W-gQz_RGBnZ2KZLTJCPuO0wMNHT6TpVFggR8NrYNQ2ktKiuXfAOxS-nmKE61YP2zjyiT9uaETdr_OvRn6fnX2m4JJZHZ-H5ue4qZaNcaleWwHMw9WYFuVwyjwmJHn-ckE5VOwDxJ1DMV3xBLEzBGAp2Jb67EaC-ijUw13WM3-YrhJWHOsOXJxxFpNImhcrg0RRV4VTrs9SkOrVBqMM-GlhCFI32TPwYfJ72jMrM9fgpPn7RSmRaxsYaEkZ0UsCAeqL2tlUQJBFIfqPHG6ojA7sA5h4KdfIjXal7Y4UNZQ8FFrRRp3E9RIQ9KzGK7biEFkK0o5imCmuzhoUtK9aD52cfLE32uS1Suhk7z0DRWM',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7191649, 'lng': -4.4194584},
#     'viewport': {'northeast': {'lat': 36.72045148029149,
#       'lng': -4.418054219708497},
#      'southwest': {'lat': 36.71775351970849, 'lng': -4.420752180291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'AC Hotel by Marriott Malaga Palacio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111941904472487664040">AC Hotel by Marriott Malaga Palacio</a>'],
#      'photo_reference': 'CmRZAAAAhPS6kbOPatRVD2AmQ5VfVNQiJzRrtkYvzO-hnhZyPCbBUQA06JoY9E0LaCY7d7zO9ni2xDAOAVZqvHDaNzvjQaWqfdP7mT1ljh5yxHnErMaT52FCM_66rJya6t5g48R4EhDrzJrYMDvH62YyoPgFUVgJGhRCqKHiCaGk1kqaLJQ6_XcYOUTR3A',
#      'width': 2048}],
#    'place_id': 'ChIJPSos4JT3cg0RbIoBy1Z8cqs',
#    'plus_code': {'compound_code': 'PH9J+M6 Málaga, Spain',
#     'global_code': '8C8QPH9J+M6'},
#    'rating': 4.4,
#    'reference': 'ChIJPSos4JT3cg0RbIoBy1Z8cqs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3746,
#    'vicinity': 'Calle Cortina del Muelle, 1, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7331581, 'lng': -4.4151449},
#     'viewport': {'northeast': {'lat': 36.7344736302915,
#       'lng': -4.413784819708497},
#      'southwest': {'lat': 36.7317756697085, 'lng': -4.416482780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Zenit Malaga',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105502464167451229944">cristina llorente</a>'],
#      'photo_reference': 'CmRaAAAAsz5At3vr_jRt_DPoZ_XHkgutZjGd8DJCi6q-NV_Uw74zgqY8oIS50QiCfNn-aDyPh3hb-fw-W3eiCP8gaGSD8nX16FoeKPOCwfrJGzQSWRoF8vi71cmzq_1iLaiGucryEhDENhEXf6YVpNFmBiqmxTPVGhTNvH3nwi8zHuJG08sjHJGSoMHepw',
#      'width': 3024}],
#    'place_id': 'ChIJzz_9hsj3cg0RSnNBj_jg7L0',
#    'plus_code': {'compound_code': 'PHMM+7W Málaga, Spain',
#     'global_code': '8C8QPHMM+7W'},
#    'rating': 4.1,
#    'reference': 'ChIJzz_9hsj3cg0RSnNBj_jg7L0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 745,
#    'vicinity': 'Calle Cuba, 1, 3, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.00469, 'lng': -4.602932999999999},
#     'viewport': {'northeast': {'lat': 37.0060805302915,
#       'lng': -4.601549219708498},
#      'southwest': {'lat': 37.0033825697085, 'lng': -4.604247180291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Convento de la Magdalena',
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110608691792795753924">Hotel Convento La Magdalena</a>'],
#      'photo_reference': 'CmRaAAAAuUazNIZDyXcS24pwgBxzm_2CerBWbISu9na_XqaHrCx2ehjkil1msBA6mOb1U6QVUulWE0mSerX94tg0LUCklVtFAM95M8nDE00Li7RMxxptr9KETLddhJY1Wo_zWsfQEhAeCr-qcysSnaPjjce5fq_zGhTaG0oRVyE5tLZFieOYgTMfdD3NkQ',
#      'width': 600}],
#    'place_id': 'ChIJNZ6mOt6Pcg0R1uN3AyCm82E',
#    'plus_code': {'compound_code': '293W+VR Antequera, Spain',
#     'global_code': '8C9Q293W+VR'},
#    'rating': 4.4,
#    'reference': 'ChIJNZ6mOt6Pcg0R1uN3AyCm82E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 656,
#    'vicinity': 'Urb. Antequera Golf Finca de la Magdalena, s/n, Antequera'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7207558, 'lng': -4.4213615},
#     'viewport': {'northeast': {'lat': 36.72212643029151,
#       'lng': -4.420028719708498},
#      'southwest': {'lat': 36.71942846970851, 'lng': -4.422726680291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Petit Palace Plaza Málaga',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108481561277832380530">Petit Palace Plaza Málaga</a>'],
#      'photo_reference': 'CmRaAAAAzEj_w8KcS-DuGftUC84sSxmKn9nI0DCNjaWJSQc-YC3aHrK4TAFWYaivrjS05KG0iwOlKD--kEf2gnfCvoz3dufx22TfGCVj8DG27f02478irctxXl-t5V0U_nA6aBLDEhBZZeBxurvXIIkGNQr-KY6qGhSVdONF4MQjOBvoHauQfz8NVl82xQ',
#      'width': 5760}],
#    'place_id': 'ChIJLaoQmpX3cg0RpVPnXNkrGLY',
#    'plus_code': {'compound_code': 'PHCH+8F Málaga, Spain',
#     'global_code': '8C8QPHCH+8F'},
#    'rating': 4.4,
#    'reference': 'ChIJLaoQmpX3cg0RpVPnXNkrGLY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 960,
#    'vicinity': 'Calle Nicasio Calle, 3, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7135232, 'lng': -4.4392423},
#     'viewport': {'northeast': {'lat': 36.7148056302915,
#       'lng': -4.437839919708497},
#      'southwest': {'lat': 36.7121076697085, 'lng': -4.440537880291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Goartín',
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115912545281749983944">Damir Grguric</a>'],
#      'photo_reference': 'CmRaAAAAZyS_qd-Z_HCoxZ26MuqF8X_8SFg84dvo8pSVHZf5gTaB0QKbzj9h6EIOXEjbLuU38vAhZMZXi6vsUFyM9FiFVv1Cuulprfmtl7FiOpVg0XC6fUmmSRgxLKdP5feCw7KgEhA90yRwdtkhWtRsJaaxHQcDGhTW-sSNXqFqgxuOjkyo20b7MKE46g',
#      'width': 5312}],
#    'place_id': 'ChIJDyMkL3b3cg0RPRKcnEBRYNg',
#    'plus_code': {'compound_code': 'PH76+C8 Málaga, Spain',
#     'global_code': '8C8QPH76+C8'},
#    'rating': 4.3,
#    'reference': 'ChIJDyMkL3b3cg0RPRKcnEBRYNg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 273,
#    'vicinity': 'Calle Gerona, 32, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.72111110000001,
#      'lng': -4.410833300000001},
#     'viewport': {'northeast': {'lat': 36.7224071802915,
#       'lng': -4.409487569708498},
#      'southwest': {'lat': 36.71970921970851, 'lng': -4.412185530291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Málaga Hotel Elíseos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115993242829169991297">Málaga Hotel Eliseos</a>'],
#      'photo_reference': 'CmRaAAAARtCv12fUxQblcQNlAqvBHJQu0E-_p7osdlc1YwNzwM-YIrBhAf2DLH8NUcFSbdtWd3V5N8Uny67MSZXJ0heFnDl9HJe1urWDGWRhCb2UdVjzNGYNTRYq_gCn4ymHyQMaEhCHfLjmalQ4_5DLuK1PLHIxGhQR76MYPNTiHniztJtAe9Pe4EESZQ',
#      'width': 2400}],
#    'place_id': 'ChIJeUp1zOn3cg0RgEnXHR8zWTQ',
#    'plus_code': {'compound_code': 'PHCQ+CM Málaga, Spain',
#     'global_code': '8C8QPHCQ+CM'},
#    'rating': 3.7,
#    'reference': 'ChIJeUp1zOn3cg0RgEnXHR8zWTQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 580,
#    'vicinity': 'Paseo Reding, 19, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7190459, 'lng': -4.4200867},
#     'viewport': {'northeast': {'lat': 36.72040013029149,
#       'lng': -4.418640919708498},
#      'southwest': {'lat': 36.7177021697085, 'lng': -4.421338880291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Molina Lario',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 427,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103587152847808962398">Hotel Molina Lario</a>'],
#      'photo_reference': 'CmRaAAAAV-DgioUuzTur2ltm8tsC2_y-0NqfGdoLUBWQl8IcEfTV3lE8_OFtwzIMzhOAfhPC2uxse3H6pPdti3VNrhUj_3IahUnlo5NSn-8qzT2GIYmVAbogzG9G0fTJjhT9avMbEhDsE0zZKLMSW3RxVB8q5yY4GhQ2fMakgby-eCJY5QGoCDbQ5FMF4A',
#      'width': 640}],
#    'place_id': 'ChIJccjjHJX3cg0Rp9QrcuOtwSg',
#    'plus_code': {'compound_code': 'PH9H+JX Málaga, Spain',
#     'global_code': '8C8QPH9H+JX'},
#    'rating': 4.4,
#    'reference': 'ChIJccjjHJX3cg0Rp9QrcuOtwSg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1211,
#    'vicinity': 'Calle Molina Lario, 20, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.723692, 'lng': -4.4192987},
#     'viewport': {'northeast': {'lat': 36.7250400802915,
#       'lng': -4.417950469708497},
#      'southwest': {'lat': 36.7223421197085, 'lng': -4.420648430291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Del Pintor',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 500,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117164154986011001819">Hotel Del Pintor</a>'],
#      'photo_reference': 'CmRaAAAAIGENZA4txP2bL1EDGAAPPmQZV38-CXRbY76WGca7QI-rUnMsHRPlgZ3n1-gdfWOEGN6QMaTeKXWF6cWV7I8y0N0hPETpUdUOtOMCgsIaEzwEuBKMP4FRbDfXlFtYAyxjEhBwy4sWs885k8bGKspiZ2w5GhT-yDphvXlHLyA1J8jeuZUcduf83Q',
#      'width': 800}],
#    'place_id': 'ChIJw59jl7_3cg0R8j_xGDWAnH4',
#    'plus_code': {'compound_code': 'PHFJ+F7 Málaga, Spain',
#     'global_code': '8C8QPHFJ+F7'},
#    'rating': 4.3,
#    'reference': 'ChIJw59jl7_3cg0R8j_xGDWAnH4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 267,
#    'vicinity': 'Calle Álamos, 27, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.72275729999999, 'lng': -4.41025},
#     'viewport': {'northeast': {'lat': 36.7240436302915,
#       'lng': -4.408758119708497},
#      'southwest': {'lat': 36.7213456697085, 'lng': -4.411456080291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Parador de Málaga Gibralfaro',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4313,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118333366796775272442">Parador de Málaga Gibralfaro</a>'],
#      'photo_reference': 'CmRaAAAACPbC6Szpr8OpUhk2uMciaLtXGwGmQ9SoE32OB21KV1ybzpQHvUaNRZKZh9zNxaFvUMyzJW2iCBNco5H3dwtGpSO3fFUvJwO7qZcAcpbQ7ZxQf_Xhvenysi3pWSQkeWeBEhBuhHANu2uwAfGqrORcn61_GhTJm94_3H0VUiFeDdOHYbVr7FYKQw',
#      'width': 6237}],
#    'place_id': 'ChIJA2MKXcL3cg0RTZB1orHi2dY',
#    'plus_code': {'compound_code': 'PHFQ+4W Málaga, Spain',
#     'global_code': '8C8QPHFQ+4W'},
#    'rating': 4.4,
#    'reference': 'ChIJA2MKXcL3cg0RTZB1orHi2dY',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1986,
#    'vicinity': 'Castillo de Gibralfaro, s/n, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7220784, 'lng': -4.401398400000001},
#     'viewport': {'northeast': {'lat': 36.72331563029149,
#       'lng': -4.399988519708498},
#      'southwest': {'lat': 36.7206176697085, 'lng': -4.402686480291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Soho Los Naranjos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3267,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105512280184181623248">Hotel Soho Los Naranjos</a>'],
#      'photo_reference': 'CmRaAAAApmdBXW3IDrD1LnmO3MXjynQS3gzKYznpvtveljGtrTABMVKoTsUEzGzd5ckVcgHBZ33kROYX3_tl9__MN-390vbQ8kHRAaDCzlgpWk8wIlB3Tk3W_UtAaotYa52FUY7FEhDGKjHNmEC__8538hVZZuiIGhRGeEetdqMyNPqAtQQfrK7G4E5GZg',
#      'width': 4900}],
#    'place_id': 'ChIJsSHpmOD3cg0RI6x1-5ngObk',
#    'plus_code': {'compound_code': 'PHCX+RC Málaga, Spain',
#     'global_code': '8C8QPHCX+RC'},
#    'rating': 4,
#    'reference': 'ChIJsSHpmOD3cg0RI6x1-5ngObk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 372,
#    'vicinity': 'Paseo de Sancha, 35, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.73136100000001, 'lng': -4.549282},
#     'viewport': {'northeast': {'lat': 36.7328747302915,
#       'lng': -4.548039419708498},
#      'southwest': {'lat': 36.7301767697085, 'lng': -4.550737380291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Posadas de España - Málaga',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109110193478151843928">Hotel Posadas de España - Málaga</a>'],
#      'photo_reference': 'CmRaAAAAmqs4LQ7A3HHIR3rB7w7ykEa70JMqu-dUOvT3M2AaVYHgS-EUsTcVFTwZno0CZy-BnOIFsHNgMghhNoBH-cuKVyjH04XhNMZ9bRbxhdEeKEhspzmKWuCe-lbdDkH1UZL8EhCh95FJbZxLv-jpox2za1hGGhRqqrObxtOTfDlUkcD2efE53OdpQw',
#      'width': 3543}],
#    'place_id': 'ChIJZaZopDHwcg0R8BVamKQ7ZTk',
#    'plus_code': {'compound_code': 'PFJ2+G7 Málaga, Spain',
#     'global_code': '8C8QPFJ2+G7'},
#    'rating': 4,
#    'reference': 'ChIJZaZopDHwcg0R8BVamKQ7ZTk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1058,
#    'vicinity': 'Calle Graham Bell, 4, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7187787, 'lng': -4.4272918},
#     'viewport': {'northeast': {'lat': 36.7201464302915,
#       'lng': -4.425912219708498},
#      'southwest': {'lat': 36.7174484697085, 'lng': -4.428610180291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Novotel Suites Malaga Centro',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110331864621194027562">Gildong Kim</a>'],
#      'photo_reference': 'CmRaAAAAy9w_j-DD2dueE-NAAZcgEcPbN5JpSyu42sB0bdlSfgdKM0CqZ8T9T9ykMoo7osb7i1lHeLuDAzeAS92-ibD5_-fR60nqLXXnakFdP3M4u6bloMpfkKvvU334RthM5ZfzEhCXKwUMHq2VHdSjoy42kmONGhRh3m-x9sr4sqg0YD_xAzhoSCVcpg',
#      'width': 4032}],
#    'place_id': 'ChIJrcyKn5f3cg0RFf3c7hW4qQU',
#    'plus_code': {'compound_code': 'PH9F+G3 Málaga, Spain',
#     'global_code': '8C8QPH9F+G3'},
#    'rating': 4.2,
#    'reference': 'ChIJrcyKn5f3cg0RFf3c7hW4qQU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 901,
#    'vicinity': 'Calle San Jacinto, 7, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.023613, 'lng': -4.560876800000001},
#     'viewport': {'northeast': {'lat': 37.0249859802915,
#       'lng': -4.559462069708498},
#      'southwest': {'lat': 37.0222880197085, 'lng': -4.562160030291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel MM Antequera (anterior Hotel Las Villas)',
#    'photos': [{'height': 667,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102987893938338925208">Hotel MM Antequera (anterior Hotel Las Villas)</a>'],
#      'photo_reference': 'CmRaAAAAfvnRCIMdD593gikhBNRTfzUOECYIidwvmCKpOfwC0-XQ19VB9h0vQwxrI-eoFfeH-720-KUmsd9zLsf_L0DTJu1LY88gvjAIdmtuB3Wqxi_sbXtJa4ynr2gBoFPs-ygpEhCK1g22p-8RYPOIOy5-Q44WGhQBy8OanwQVrDYhx_xmM-i9dUNOOQ',
#      'width': 1000}],
#    'place_id': 'ChIJd9TaIeaPcg0RvQ0n2L_vzwQ',
#    'plus_code': {'compound_code': '2CFQ+CJ Antequera, Spain',
#     'global_code': '8C9Q2CFQ+CJ'},
#    'rating': 3.7,
#    'reference': 'ChIJd9TaIeaPcg0RvQ0n2L_vzwQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 426,
#    'vicinity': 'AVD CRUZ BLANCA, 1, Antequera'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.72077, 'lng': -4.4218041},
#     'viewport': {'northeast': {'lat': 36.72210123029149,
#       'lng': -4.420405119708498},
#      'southwest': {'lat': 36.7194032697085, 'lng': -4.423103080291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Room Mate Larios Hotel',
#    'photos': [{'height': 3648,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100363841405468128223">Room Mate Larios Hotel</a>'],
#      'photo_reference': 'CmRaAAAAIJ_1MwU8rwr2Cnts4S8bAu95o2dUIeSEjMCH7Ewua-fNJfeqSsuWqz9Rn_E-B-CEjOGmMXlmytEkl9OXkaaYUKZ1Okix3yIhXZ01l1ritoslf1zVLcG7quQbpCcSPzCxEhCpphiaaFEraop0DvTLkRJlGhTWLKQS8YquX29rzRC7HRJh1FwC4w',
#      'width': 5472}],
#    'place_id': 'ChIJtWOtlpX3cg0RTxCNM1P7maQ',
#    'plus_code': {'compound_code': 'PHCH+87 Málaga, Spain',
#     'global_code': '8C8QPHCH+87'},
#    'rating': 4.4,
#    'reference': 'ChIJtWOtlpX3cg0RTxCNM1P7maQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1025,
#    'vicinity': 'Calle Marqués de Larios, 2, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7113694, 'lng': -4.4320767},
#     'viewport': {'northeast': {'lat': 36.7126480302915,
#       'lng': -4.430676719708497},
#      'southwest': {'lat': 36.7099500697085, 'lng': -4.433374680291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Barceló Málaga',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1733,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108018643700247385404">Barceló Málaga</a>'],
#      'photo_reference': 'CmRaAAAA6bsblZB68nEayNUjPECJBy8egyR71lbtxjPzkdE42m-SHTaJ1p6XT0G2n8aAZi2y6tTgqr5aJ8osHkUbrUoJ316BPV7Van-1_refPGBu9ekbtgLdpwxm2M-69ullktmyEhAtmt26e1VfOtHJAAXHD46LGhRgVniL1B8I312g8jZbtN55MZ7E_w',
#      'width': 2600}],
#    'place_id': 'ChIJV3xT2Zr3cg0RgF9I3qOsAI8',
#    'plus_code': {'compound_code': 'PH69+G5 Málaga, Spain',
#     'global_code': '8C8QPH69+G5'},
#    'rating': 4.5,
#    'reference': 'ChIJV3xT2Zr3cg0RgF9I3qOsAI8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1512,
#    'vicinity': 'Calle Héroe de Sostoa, 2, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7362436, 'lng': -4.4747779},
#     'viewport': {'northeast': {'lat': 36.73765693029151,
#       'lng': -4.473390669708498},
#      'southwest': {'lat': 36.73495896970851, 'lng': -4.476088630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Villa Guadalupe / Restaurante Amador',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4828,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102728432154467999539">Hotel Villa Guadalupe / Restaurante Amador</a>'],
#      'photo_reference': 'CmRaAAAABmVp4Nw2VUVwv2M6FpYDNDtOhedDjZaqwzbwvWVckOdUzCua3k1RbM_8YCN3gNGKup9C07V72AoQRCIcDJwSbFUCutP4DWo1yRkt2ModzfVLhpe-tWkX0Yl_BKwRDtJCEhCnirvM50edSIIKjVJLXK2SGhR8MroK96FBW_16FdFmSk6-r7yCXQ',
#      'width': 7234}],
#    'place_id': 'ChIJhUrwVin3cg0RW2JvJgfij1c',
#    'plus_code': {'compound_code': 'PGPG+F3 Málaga, Spain',
#     'global_code': '8C8QPGPG+F3'},
#    'rating': 4.6,
#    'reference': 'ChIJhUrwVin3cg0RW2JvJgfij1c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 223,
#    'vicinity': 'Urb, Calle de Bandaneira, 6, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.71891779999999, 'lng': -4.420774},
#     'viewport': {'northeast': {'lat': 36.72023353029149,
#       'lng': -4.419410169708497},
#      'southwest': {'lat': 36.7175355697085, 'lng': -4.422108130291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Don Curro Malaga',
#    'photos': [{'height': 900,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113064487111474196039">Hotel Don Curro Malaga</a>'],
#      'photo_reference': 'CmRaAAAAe9cincZjbbbUFlKUGH5CHL63U9eBbkvFE1ZoTL3Zj9BDcwe8uI1btm1_7lWj3YFwPKzi-tYQCwvAzUp1ptTeHUx4hTS5-EvPCcvuHdHVtT3RSVu1h6GaNBPAIrlYysDyEhBe6P43ea3TYlJvGDz3O8OeGhR-XrzuqWAye875BVUxBpOumzqi7g',
#      'width': 1800}],
#    'place_id': 'ChIJmezb_5T3cg0RTSDOWJhv3jE',
#    'plus_code': {'compound_code': 'PH9H+HM Málaga, Spain',
#     'global_code': '8C8QPH9H+HM'},
#    'rating': 4,
#    'reference': 'ChIJmezb_5T3cg0RTSDOWJhv3jE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1098,
#    'vicinity': 'Calle Sancha de Lara, 9, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7224762, 'lng': -4.366400200000001},
#     'viewport': {'northeast': {'lat': 36.72382478029149,
#       'lng': -4.365005619708498},
#      'southwest': {'lat': 36.7211268197085, 'lng': -4.367703580291503}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Málaga Hostel Bed & Beachfast',
#    'photos': [{'height': 900,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112928297314201730852">LA MORAGA DE PONIENTE-MALAGA HOSTEL</a>'],
#      'photo_reference': 'CmRaAAAAkHiKKoQS8406TudIMqL6yCQODHpwVwtXrOpRXMpBeHhawR4E417sGyqV1b9GTeqhLVFrs7bqNe4E2pp6GCGvKruad-EeXXQ6mNneKHWmZVOvuQTI1x_fmi4Dlb7hkodjEhAjU9CjIdtqMMEOcJahU6ItGhQFGr485M4DFcXIlcTSJ09qde4l_A',
#      'width': 602}],
#    'place_id': 'ChIJXbNe8zdYcg0Rrs9aNjzyu5A',
#    'plus_code': {'compound_code': 'PJCM+XC Málaga, Spain',
#     'global_code': '8C8QPJCM+XC'},
#    'rating': 3.9,
#    'reference': 'ChIJXbNe8zdYcg0Rrs9aNjzyu5A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 123,
#    'vicinity': 'Calle Conde de las Navas, 1, Málaga'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7138, 'lng': -4.275759999999999},
#     'viewport': {'northeast': {'lat': 36.7152516302915,
#       'lng': -4.274393069708497},
#      'southwest': {'lat': 36.7125536697085, 'lng': -4.277091030291501}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Elimar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2360,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111870363865268922091">Hotel Elimar</a>'],
#      'photo_reference': 'CmRaAAAA7hwv2sSPFp0i8__W4FfVVdIkhlK6UyJG90n33fhZnCxYOmO0Wb5C9YaPBXbNVzuMG4FIo-usygGho-t3jvgaFlQ6GceYM--VDBCwpdgOR34of8LUMHQd7uoua-0sqLBwEhC8BhctUCjCvJsYbSGA-0ybGhTnsjc9_l8RsaE1THnhhRrwglQphQ',
#      'width': 4043}],
#    'place_id': 'ChIJPZhhC31acg0RkBZ3It4OZFE',
#    'plus_code': {'compound_code': 'PP7F+GM Rincón de la Victoria, Spain',
#     'global_code': '8C8QPP7F+GM'},
#    'rating': 3.8,
#    'reference': 'ChIJPZhhC31acg0RkBZ3It4OZFE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 922,
#    'vicinity': 'Avenida del Mediterráneo, 230, Rincón de la Victoria'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.7155561, 'lng': -4.423596799999999},
#     'viewport': {'northeast': {'lat': 36.7169042302915,
#       'lng': -4.422250669708498},
#      'southwest': {'lat': 36.71420626970851, 'lng': -4.424948630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hotel Soho Boutique Bahía Málaga',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3744,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114502053532328373175">Hotel Soho Bahía Málaga</a>'],
#      'photo_reference': 'CmRaAAAA6hgWlgAysfKnto_arSRIexfI1pfyomt3I5RY8EhR6JczDBT_j-zWpaXMD9ATCIxYGI4D5vQmKC_1vnJ9WNAhyuHRGyWcgOgQydcz0-U_YNrj0ICLbTkbNluwONp9HW1hEhD0h54IYQREoZZfi5uJ5h4nGhTcEfjs4DVolNEIG9yirrhZ1HUzGA',
#      'width': 5616}],
#    'place_id': 'ChIJhaskV5H3cg0RLfByJU_Jd0s',
#    'plus_code': {'compound_code': 'PH8G+6H Málaga, Spain',
#     'global_code': '8C8QPH8G+6H'},
#    'rating': 3.9,
#    'reference': 'ChIJhaskV5H3cg0RLfByJU_Jd0s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 503,
#    'vicinity': 'Calle Somera, 8, Málaga'}],
#  'status': 'OK'}

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
